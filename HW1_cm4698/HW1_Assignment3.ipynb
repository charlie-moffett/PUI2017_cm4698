# %%
from __future__ import print_function
__author__ = "Charlie Moffett, CUSP NYU 2017"

# %%
import os
import sys

# you can use the numpy library for random number generation: 
# http://docs.scipy.org/doc/numpy/reference/routines.random.html

import numpy as np

# %%
np.random.seed(42)

# %%
RepRand = np.random.randn(2, 100)

# %%
RepRand.shape
# Out:
# (2, 100)

# %%
RepRandAll = np.random.randn(50, 2, 100)

# %%
RepRandAll = np.zeros((50, 2, 100))
for i in range(50):
    RepRandAll[i] = np.random.randint(1, 12) * np.random.randn(2, 100) + np.random.randint(1, 12)

# %%
RepRandAll.shape
# Out:
# (50, 2, 100)

# %%
#RepRandAll

# %%
import pylab as pl
# %pylab inline

for i in range(50):
    plt.plot(RepRandAll[i,0], RepRandAll[i,1], 'o')
plot()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# []

# %%
for i in range(50):
    for j in range(100):
        pl.plot(randn()*RepRandAll[i][0][j]+randn(),randn()*RepRandAll[i][1][j]+randn(),'.')
plot()
# Out:
# []
