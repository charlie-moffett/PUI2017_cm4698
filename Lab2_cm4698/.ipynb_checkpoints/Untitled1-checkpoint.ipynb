# %%
import pylab as pl
import os
import json
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

# %pylab inline
pl.rc('font', size=15)

#key = sys.argv[1]
#key = os.getenv("MTAKEY")
#line = sys.argv[2]
#line = 52

url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=7622fbc4-4694-49b1-90d2-0a89296b59ea&VehicleMonitoringDetailLevel=calls&LineRef=B52"

#url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=" + key + \
#   "a&VehicleMonitoringDetailLevel=calls&LineRef" + line

print (url)
response = urllib.urlopen(url)
data = response.read().decode("utf-8")
data = json.loads(data)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=7622fbc4-4694-49b1-90d2-0a89296b59ea&VehicleMonitoringDetailLevel=calls&LineRef=B52

# %%
(type(data))
# Out:
# dict

# %%
data.keys()
# Out:
# [u'Siri']

# %%
data['Siri']['ServiceDelivery'].keys()
# Out:
# [u'SituationExchangeDelivery',
#  u'ResponseTimestamp',
#  u'VehicleMonitoringDelivery']

# %%
data['Siri']
# Out:
# {u'ServiceDelivery': {u'ResponseTimestamp': u'2017-09-21T13:51:26.938-04:00',
#   u'SituationExchangeDelivery': [],
#   u'VehicleMonitoringDelivery': [{u'ResponseTimestamp': u'2017-09-21T13:51:26.938-04:00',
#     u'ValidUntil': u'2017-09-21T13:52:26.938-04:00',
#     u'VehicleActivity': [{u'MonitoredVehicleJourney': {u'Bearing': 186.5081,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday_C_FP_46980_B52-124',
#        u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#        u'DestinationRef': u'MTA_901463',
#        u'DirectionRef': u'1',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-21',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-079500_B52_124'},
#        u'JourneyPatternRef': u'MTA_B520048',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-21T13:51:27.938-04:00',
#         u'ExpectedDepartureTime': u'2017-09-21T13:51:27.938-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4864.08,
#           u'DistanceFromCall': 2.55,
#           u'PresentableDistance': u'at stop',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'GATES AV/CLASSON AV',
#         u'StopPointRef': u'MTA_307948',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-21T13:51:26.938-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4864.08,
#             u'DistanceFromCall': 2.55,
#             u'PresentableDistance': u'at stop',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'GATES AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307948'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:52:35.145-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5156.7,
#             u'DistanceFromCall': 295.17,
#             u'PresentableDistance': u'1 stop away',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'GREENE AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307572'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:53:45.745-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5398.69,
#             u'DistanceFromCall': 537.16,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'GREENE AV/GRAND AV',
#           u'StopPointRef': u'MTA_307573'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:55:30.849-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5656.47,
#             u'DistanceFromCall': 794.94,
#             u'PresentableDistance': u'3 stops away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'GREENE AV/WASHINGTON AV',
#           u'StopPointRef': u'MTA_307596'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:57:01.992-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5908.9,
#             u'DistanceFromCall': 1047.37,
#             u'PresentableDistance': u'0.7 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'GREENE AV/VANDERBILT AV',
#           u'StopPointRef': u'MTA_307575'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:57:52.992-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.28,
#             u'DistanceFromCall': 1213.75,
#             u'PresentableDistance': u'0.8 miles away',
#             u'StopsFromCall': 5}},
#           u'StopPointName': u'GREENE AV/ADELPHI ST',
#           u'StopPointRef': u'MTA_307576'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:58:56.592-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6239.48,
#             u'DistanceFromCall': 1377.95,
#             u'PresentableDistance': u'0.9 miles away',
#             u'StopsFromCall': 6}},
#           u'StopPointName': u'GREENE AV/CUMBERLAND ST',
#           u'StopPointRef': u'MTA_307577'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:01:08.017-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6482.4,
#             u'DistanceFromCall': 1620.87,
#             u'PresentableDistance': u'1.0 miles away',
#             u'StopsFromCall': 7}},
#           u'StopPointName': u'FULTON ST/S ELLIOTT PL',
#           u'StopPointRef': u'MTA_302427'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:02:24.617-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6639.55,
#             u'DistanceFromCall': 1778.02,
#             u'PresentableDistance': u'1.1 miles away',
#             u'StopsFromCall': 8}},
#           u'StopPointName': u'FULTON ST/FT GREENE PL',
#           u'StopPointRef': u'MTA_302428'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:04:06.417-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6938.8,
#             u'DistanceFromCall': 2077.27,
#             u'PresentableDistance': u'1.3 miles away',
#             u'StopsFromCall': 9}},
#           u'StopPointName': u'FULTON ST/HUDSON AV',
#           u'StopPointRef': u'MTA_302430'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:06:09.217-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7188.7,
#             u'DistanceFromCall': 2327.17,
#             u'PresentableDistance': u'1.4 miles away',
#             u'StopsFromCall': 10}},
#           u'StopPointName': u'FULTON ST/BOND ST',
#           u'StopPointRef': u'MTA_302431'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:07:31.017-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7394.01,
#             u'DistanceFromCall': 2532.47,
#             u'PresentableDistance': u'1.6 miles away',
#             u'StopsFromCall': 11}},
#           u'StopPointName': u'FULTON ST/DUFFIELD ST',
#           u'StopPointRef': u'MTA_307492'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:08:59.177-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7604.3,
#             u'DistanceFromCall': 2742.77,
#             u'PresentableDistance': u'1.7 miles away',
#             u'StopsFromCall': 12}},
#           u'StopPointName': u'FULTON ST/JAY ST',
#           u'StopPointRef': u'MTA_302433'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:11:46.177-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7929.74,
#             u'DistanceFromCall': 3068.21,
#             u'PresentableDistance': u'1.9 miles away',
#             u'StopsFromCall': 13}},
#           u'StopPointName': u'JORALEMON ST/COURT ST',
#           u'StopPointRef': u'MTA_302434'},
#          {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8059.65,
#             u'DistanceFromCall': 3198.12,
#             u'PresentableDistance': u'2.0 miles away',
#             u'StopsFromCall': 14}},
#           u'StopPointName': u'CADMAN PLZ W/MONTAGUE ST',
#           u'StopPointRef': u'MTA_306533'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:13:18.977-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91,
#             u'DistanceFromCall': 3236.38,
#             u'PresentableDistance': u'2.0 miles away',
#             u'StopsFromCall': 15}},
#           u'StopPointName': u'CADMAN PZ W/TILLARY ST',
#           u'StopPointRef': u'MTA_901463'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_504965',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.685235, u'Longitude': -73.959113},
#        u'VehicleRef': u'MTA NYCT_3984'},
#       u'RecordedAtTime': u'2017-09-21T13:50:42.000-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 186.61346,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday_C_FP_19200_B52-105',
#        u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#        u'DestinationRef': u'MTA_901463',
#        u'DirectionRef': u'1',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-21',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-080300_B52_122'},
#        u'JourneyPatternRef': u'MTA_B520048',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-21T13:51:27.938-04:00',
#         u'ExpectedDepartureTime': u'2017-09-21T13:51:27.938-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3902.63,
#           u'DistanceFromCall': 2.7,
#           u'PresentableDistance': u'at stop',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'GATES AV/MARCY AV',
#         u'StopPointRef': u'MTA_304211',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-21T13:51:26.938-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3902.63,
#             u'DistanceFromCall': 2.7,
#             u'PresentableDistance': u'at stop',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'GATES AV/MARCY AV',
#           u'StopPointRef': u'MTA_304211'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:53:19.479-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4182.76,
#             u'DistanceFromCall': 282.82,
#             u'PresentableDistance': u'1 stop away',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'GATES AV/NOSTRAND AV',
#           u'StopPointRef': u'MTA_304212'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:55:22.585-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4496.51,
#             u'DistanceFromCall': 596.58,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'GATES AV/BEDFORD AV',
#           u'StopPointRef': u'MTA_304213'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:56:44.687-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4675.5,
#             u'DistanceFromCall': 775.56,
#             u'PresentableDistance': u'3 stops away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'GATES AV/FRANKLIN AV',
#           u'StopPointRef': u'MTA_304214'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:57:39.830-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4864.08,
#             u'DistanceFromCall': 964.14,
#             u'PresentableDistance': u'0.6 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'GATES AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307948'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:59:32.230-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5156.7,
#             u'DistanceFromCall': 1256.76,
#             u'PresentableDistance': u'0.8 miles away',
#             u'StopsFromCall': 5}},
#           u'StopPointName': u'GREENE AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307572'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:00:42.830-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5398.69,
#             u'DistanceFromCall': 1498.76,
#             u'PresentableDistance': u'0.9 miles away',
#             u'StopsFromCall': 6}},
#           u'StopPointName': u'GREENE AV/GRAND AV',
#           u'StopPointRef': u'MTA_307573'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:02:27.934-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5656.47,
#             u'DistanceFromCall': 1756.54,
#             u'PresentableDistance': u'1.1 miles away',
#             u'StopsFromCall': 7}},
#           u'StopPointName': u'GREENE AV/WASHINGTON AV',
#           u'StopPointRef': u'MTA_307596'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:03:59.077-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5908.9,
#             u'DistanceFromCall': 2008.97,
#             u'PresentableDistance': u'1.2 miles away',
#             u'StopsFromCall': 8}},
#           u'StopPointName': u'GREENE AV/VANDERBILT AV',
#           u'StopPointRef': u'MTA_307575'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:04:57.368-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.28,
#             u'DistanceFromCall': 2175.35,
#             u'PresentableDistance': u'1.4 miles away',
#             u'StopsFromCall': 9}},
#           u'StopPointName': u'GREENE AV/ADELPHI ST',
#           u'StopPointRef': u'MTA_307576'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:06:00.968-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6239.48,
#             u'DistanceFromCall': 2339.55,
#             u'PresentableDistance': u'1.5 miles away',
#             u'StopsFromCall': 10}},
#           u'StopPointName': u'GREENE AV/CUMBERLAND ST',
#           u'StopPointRef': u'MTA_307577'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:08:12.393-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6482.4,
#             u'DistanceFromCall': 2582.46,
#             u'PresentableDistance': u'1.6 miles away',
#             u'StopsFromCall': 11}},
#           u'StopPointName': u'FULTON ST/S ELLIOTT PL',
#           u'StopPointRef': u'MTA_302427'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:09:28.993-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6639.55,
#             u'DistanceFromCall': 2739.61,
#             u'PresentableDistance': u'1.7 miles away',
#             u'StopsFromCall': 12}},
#           u'StopPointName': u'FULTON ST/FT GREENE PL',
#           u'StopPointRef': u'MTA_302428'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:11:10.793-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6938.8,
#             u'DistanceFromCall': 3038.87,
#             u'PresentableDistance': u'1.9 miles away',
#             u'StopsFromCall': 13}},
#           u'StopPointName': u'FULTON ST/HUDSON AV',
#           u'StopPointRef': u'MTA_302430'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:13:13.993-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7188.7,
#             u'DistanceFromCall': 3288.77,
#             u'PresentableDistance': u'2.0 miles away',
#             u'StopsFromCall': 14}},
#           u'StopPointName': u'FULTON ST/BOND ST',
#           u'StopPointRef': u'MTA_302431'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:14:35.793-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7394.01,
#             u'DistanceFromCall': 3494.07,
#             u'PresentableDistance': u'2.2 miles away',
#             u'StopsFromCall': 15}},
#           u'StopPointName': u'FULTON ST/DUFFIELD ST',
#           u'StopPointRef': u'MTA_307492'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:16:03.953-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7604.3,
#             u'DistanceFromCall': 3704.36,
#             u'PresentableDistance': u'2.3 miles away',
#             u'StopsFromCall': 16}},
#           u'StopPointName': u'FULTON ST/JAY ST',
#           u'StopPointRef': u'MTA_302433'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:18:50.953-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7929.74,
#             u'DistanceFromCall': 4029.8,
#             u'PresentableDistance': u'2.5 miles away',
#             u'StopsFromCall': 17}},
#           u'StopPointName': u'JORALEMON ST/COURT ST',
#           u'StopPointRef': u'MTA_302434'},
#          {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8059.65,
#             u'DistanceFromCall': 4159.72,
#             u'PresentableDistance': u'2.6 miles away',
#             u'StopsFromCall': 18}},
#           u'StopPointName': u'CADMAN PLZ W/MONTAGUE ST',
#           u'StopPointRef': u'MTA_306533'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:20:24.153-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91,
#             u'DistanceFromCall': 4197.98,
#             u'PresentableDistance': u'2.6 miles away',
#             u'StopsFromCall': 19}},
#           u'StopPointName': u'CADMAN PZ W/TILLARY ST',
#           u'StopPointRef': u'MTA_901463'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_504965',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.686534, u'Longitude': -73.947838},
#        u'VehicleRef': u'MTA NYCT_3990'},
#       u'RecordedAtTime': u'2017-09-21T13:51:11.000-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 186.41734,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday_C_FP_26040_B52-118',
#        u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#        u'DestinationRef': u'MTA_901463',
#        u'DirectionRef': u'1',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-21',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-081000_B52_125'},
#        u'JourneyPatternRef': u'MTA_B520048',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-21T13:51:27.938-04:00',
#         u'ExpectedDepartureTime': u'2017-09-21T13:51:27.938-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1755.61,
#           u'DistanceFromCall': 6.74,
#           u'PresentableDistance': u'at stop',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'GATES AV/BROADWAY',
#         u'StopPointRef': u'MTA_308046',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-21T13:51:26.938-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1755.61,
#             u'DistanceFromCall': 6.74,
#             u'PresentableDistance': u'at stop',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'GATES AV/BROADWAY',
#           u'StopPointRef': u'MTA_308046'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:52:42.965-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1901.08,
#             u'DistanceFromCall': 152.22,
#             u'PresentableDistance': u'approaching',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'GATES AV/RALPH AV',
#           u'StopPointRef': u'MTA_304203'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:54:19.165-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2178.14,
#             u'DistanceFromCall': 429.27,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'GATES AV/PATCHEN AV',
#           u'StopPointRef': u'MTA_304204'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:55:35.024-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2430.58,
#             u'DistanceFromCall': 681.72,
#             u'PresentableDistance': u'3 stops away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'GATES AV/MALCOLM X BL',
#           u'StopPointRef': u'MTA_304205'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:57:09.624-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2679.29,
#             u'DistanceFromCall': 930.43,
#             u'PresentableDistance': u'0.6 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'GATES AV/STUYVESANT AV',
#           u'StopPointRef': u'MTA_304206'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:58:15.312-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2883.11,
#             u'DistanceFromCall': 1134.25,
#             u'PresentableDistance': u'0.7 miles away',
#             u'StopsFromCall': 5}},
#           u'StopPointName': u'GATES AV/LEWIS AV',
#           u'StopPointRef': u'MTA_304207'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:00:18.712-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3177.93,
#             u'DistanceFromCall': 1429.06,
#             u'PresentableDistance': u'0.9 miles away',
#             u'StopsFromCall': 6}},
#           u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#           u'StopPointRef': u'MTA_306530'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:01:24.112-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3373.19,
#             u'DistanceFromCall': 1624.33,
#             u'PresentableDistance': u'1.0 miles away',
#             u'StopsFromCall': 7}},
#           u'StopPointName': u'GATES AV/THROOP AV',
#           u'StopPointRef': u'MTA_304209'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:03:26.912-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3659.93,
#             u'DistanceFromCall': 1911.06,
#             u'PresentableDistance': u'1.2 miles away',
#             u'StopsFromCall': 8}},
#           u'StopPointName': u'GATES AV/TOMPKINS AV',
#           u'StopPointRef': u'MTA_304210'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:05:03.312-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3902.63,
#             u'DistanceFromCall': 2153.77,
#             u'PresentableDistance': u'1.3 miles away',
#             u'StopsFromCall': 9}},
#           u'StopPointName': u'GATES AV/MARCY AV',
#           u'StopPointRef': u'MTA_304211'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:07:10.720-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4182.76,
#             u'DistanceFromCall': 2433.89,
#             u'PresentableDistance': u'1.5 miles away',
#             u'StopsFromCall': 10}},
#           u'StopPointName': u'GATES AV/NOSTRAND AV',
#           u'StopPointRef': u'MTA_304212'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:09:13.826-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4496.51,
#             u'DistanceFromCall': 2747.65,
#             u'PresentableDistance': u'1.7 miles away',
#             u'StopsFromCall': 11}},
#           u'StopPointName': u'GATES AV/BEDFORD AV',
#           u'StopPointRef': u'MTA_304213'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:10:35.928-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4675.5,
#             u'DistanceFromCall': 2926.63,
#             u'PresentableDistance': u'1.8 miles away',
#             u'StopsFromCall': 12}},
#           u'StopPointName': u'GATES AV/FRANKLIN AV',
#           u'StopPointRef': u'MTA_304214'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:11:31.071-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4864.08,
#             u'DistanceFromCall': 3115.21,
#             u'PresentableDistance': u'1.9 miles away',
#             u'StopsFromCall': 13}},
#           u'StopPointName': u'GATES AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307948'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:13:23.471-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5156.7,
#             u'DistanceFromCall': 3407.83,
#             u'PresentableDistance': u'2.1 miles away',
#             u'StopsFromCall': 14}},
#           u'StopPointName': u'GREENE AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307572'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:14:34.071-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5398.69,
#             u'DistanceFromCall': 3649.82,
#             u'PresentableDistance': u'2.3 miles away',
#             u'StopsFromCall': 15}},
#           u'StopPointName': u'GREENE AV/GRAND AV',
#           u'StopPointRef': u'MTA_307573'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:16:19.175-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5656.47,
#             u'DistanceFromCall': 3907.6,
#             u'PresentableDistance': u'2.4 miles away',
#             u'StopsFromCall': 16}},
#           u'StopPointName': u'GREENE AV/WASHINGTON AV',
#           u'StopPointRef': u'MTA_307596'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:17:50.318-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5908.9,
#             u'DistanceFromCall': 4160.04,
#             u'PresentableDistance': u'2.6 miles away',
#             u'StopsFromCall': 17}},
#           u'StopPointName': u'GREENE AV/VANDERBILT AV',
#           u'StopPointRef': u'MTA_307575'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:18:48.609-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.28,
#             u'DistanceFromCall': 4326.41,
#             u'PresentableDistance': u'2.7 miles away',
#             u'StopsFromCall': 18}},
#           u'StopPointName': u'GREENE AV/ADELPHI ST',
#           u'StopPointRef': u'MTA_307576'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:19:52.209-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6239.48,
#             u'DistanceFromCall': 4490.62,
#             u'PresentableDistance': u'2.8 miles away',
#             u'StopsFromCall': 19}},
#           u'StopPointName': u'GREENE AV/CUMBERLAND ST',
#           u'StopPointRef': u'MTA_307577'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:22:03.634-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6482.4,
#             u'DistanceFromCall': 4733.53,
#             u'PresentableDistance': u'2.9 miles away',
#             u'StopsFromCall': 20}},
#           u'StopPointName': u'FULTON ST/S ELLIOTT PL',
#           u'StopPointRef': u'MTA_302427'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:23:20.234-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6639.55,
#             u'DistanceFromCall': 4890.68,
#             u'PresentableDistance': u'3.0 miles away',
#             u'StopsFromCall': 21}},
#           u'StopPointName': u'FULTON ST/FT GREENE PL',
#           u'StopPointRef': u'MTA_302428'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:25:02.034-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6938.8,
#             u'DistanceFromCall': 5189.94,
#             u'PresentableDistance': u'3.2 miles away',
#             u'StopsFromCall': 22}},
#           u'StopPointName': u'FULTON ST/HUDSON AV',
#           u'StopPointRef': u'MTA_302430'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:27:05.234-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7188.7,
#             u'DistanceFromCall': 5439.84,
#             u'PresentableDistance': u'3.4 miles away',
#             u'StopsFromCall': 23}},
#           u'StopPointName': u'FULTON ST/BOND ST',
#           u'StopPointRef': u'MTA_302431'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:28:27.034-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7394.01,
#             u'DistanceFromCall': 5645.14,
#             u'PresentableDistance': u'3.5 miles away',
#             u'StopsFromCall': 24}},
#           u'StopPointName': u'FULTON ST/DUFFIELD ST',
#           u'StopPointRef': u'MTA_307492'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:29:55.194-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7604.3,
#             u'DistanceFromCall': 5855.43,
#             u'PresentableDistance': u'3.6 miles away',
#             u'StopsFromCall': 25}},
#           u'StopPointName': u'FULTON ST/JAY ST',
#           u'StopPointRef': u'MTA_302433'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:32:42.194-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7929.74,
#             u'DistanceFromCall': 6180.87,
#             u'PresentableDistance': u'3.8 miles away',
#             u'StopsFromCall': 26}},
#           u'StopPointName': u'JORALEMON ST/COURT ST',
#           u'StopPointRef': u'MTA_302434'},
#          {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8059.65,
#             u'DistanceFromCall': 6310.79,
#             u'PresentableDistance': u'3.9 miles away',
#             u'StopsFromCall': 27}},
#           u'StopPointName': u'CADMAN PLZ W/MONTAGUE ST',
#           u'StopPointRef': u'MTA_306533'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:34:15.394-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91,
#             u'DistanceFromCall': 6349.05,
#             u'PresentableDistance': u'3.9 miles away',
#             u'StopsFromCall': 28}},
#           u'StopPointName': u'CADMAN PZ W/TILLARY ST',
#           u'StopPointRef': u'MTA_901463'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_504965',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.689427, u'Longitude': -73.922613},
#        u'VehicleRef': u'MTA NYCT_6569'},
#       u'RecordedAtTime': u'2017-09-21T13:51:13.000-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 6.5566864,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday_C_FP_21060_B52-107',
#        u'DestinationName': u'RIDGEWOOD TERM via GATES',
#        u'DestinationRef': u'MTA_801117',
#        u'DirectionRef': u'0',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-21',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-079300_B52_103'},
#        u'JourneyPatternRef': u'MTA_B520040',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-21T13:51:36.258-04:00',
#         u'ExpectedDepartureTime': u'2017-09-21T13:51:36.258-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6321.91,
#           u'DistanceFromCall': 43.6,
#           u'PresentableDistance': u'approaching',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'GATES AV/PATCHEN AV',
#         u'StopPointRef': u'MTA_307684',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-21T13:51:36.258-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6321.91,
#             u'DistanceFromCall': 43.6,
#             u'PresentableDistance': u'approaching',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'GATES AV/PATCHEN AV',
#           u'StopPointRef': u'MTA_307684'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:52:41.458-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6555.96,
#             u'DistanceFromCall': 277.66,
#             u'PresentableDistance': u'1 stop away',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'GATES AV/RALPH AV',
#           u'StopPointRef': u'MTA_307901'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:53:43.100-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6717.8,
#             u'DistanceFromCall': 439.49,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'GATES AV/BROADWAY',
#           u'StopPointRef': u'MTA_307686'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:55:41.490-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6962.31,
#             u'DistanceFromCall': 684.01,
#             u'PresentableDistance': u'3 stops away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'GATES AV/BUSHWICK AV',
#           u'StopPointRef': u'MTA_307687'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:56:34.538-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7131.71,
#             u'DistanceFromCall': 853.4,
#             u'PresentableDistance': u'0.5 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'GATES AV/EVERGREEN AV',
#           u'StopPointRef': u'MTA_307688'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:57:44.604-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7373.59,
#             u'DistanceFromCall': 1095.29,
#             u'PresentableDistance': u'0.7 miles away',
#             u'StopsFromCall': 5}},
#           u'StopPointName': u'GATES AV/CENTRAL AV',
#           u'StopPointRef': u'MTA_307689'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:58:49.204-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7576.02,
#             u'DistanceFromCall': 1297.72,
#             u'PresentableDistance': u'0.8 miles away',
#             u'StopsFromCall': 6}},
#           u'StopPointName': u'GATES AV/WILSON AV',
#           u'StopPointRef': u'MTA_307690'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:59:59.191-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7782.09,
#             u'DistanceFromCall': 1503.79,
#             u'PresentableDistance': u'0.9 miles away',
#             u'StopsFromCall': 7}},
#           u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#           u'StopPointRef': u'MTA_307691'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:01:22.612-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8081.37,
#             u'DistanceFromCall': 1803.07,
#             u'PresentableDistance': u'1.1 miles away',
#             u'StopsFromCall': 8}},
#           u'StopPointName': u'PALMETTO ST/IRVING AV',
#           u'StopPointRef': u'MTA_304415'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:01:58.812-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8231.28,
#             u'DistanceFromCall': 1952.98,
#             u'PresentableDistance': u'1.2 miles away',
#             u'StopsFromCall': 9}},
#           u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#           u'StopPointRef': u'MTA_801117'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_307175',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.688886, u'Longitude': -73.927378},
#        u'VehicleRef': u'MTA NYCT_4433'},
#       u'RecordedAtTime': u'2017-09-21T13:51:22.046-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 270.0,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday_C_FP_17400_B52-104',
#        u'DestinationName': u'RIDGEWOOD TERM via GATES',
#        u'DestinationRef': u'MTA_801117',
#        u'DirectionRef': u'0',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-21',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-082300_B54_215'},
#        u'JourneyPatternRef': u'MTA_B520040',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-21T13:51:27.938-04:00',
#         u'ExpectedDepartureTime': u'2017-09-21T13:51:27.938-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 598.44,
#           u'DistanceFromCall': 52.55,
#           u'PresentableDistance': u'approaching',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'ADAMS ST/BKLYN SUPREME CRT',
#         u'StopPointRef': u'MTA_307460',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-21T13:51:26.938-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 598.44,
#             u'DistanceFromCall': 52.55,
#             u'PresentableDistance': u'approaching',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'ADAMS ST/BKLYN SUPREME CRT',
#           u'StopPointRef': u'MTA_307460'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:53:19.050-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 797.4,
#             u'DistanceFromCall': 251.51,
#             u'PresentableDistance': u'1 stop away',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'FULTON ST/SMITH ST',
#           u'StopPointRef': u'MTA_302945'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:54:54.050-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 986.57,
#             u'DistanceFromCall': 440.68,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'FULTON ST/HOYT ST',
#           u'StopPointRef': u'MTA_307491'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:56:36.439-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1220.03,
#             u'DistanceFromCall': 674.15,
#             u'PresentableDistance': u'3 stops away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'FULTON ST/BOND ST',
#           u'StopPointRef': u'MTA_302947'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:58:19.639-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1393.71,
#             u'DistanceFromCall': 847.82,
#             u'PresentableDistance': u'0.5 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'FULTON ST/FLATBUSH AV EXT',
#           u'StopPointRef': u'MTA_302948'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:01:04.167-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1683.32,
#             u'DistanceFromCall': 1137.43,
#             u'PresentableDistance': u'0.7 miles away',
#             u'StopsFromCall': 5}},
#           u'StopPointName': u'FULTON ST/ASHLAND PL',
#           u'StopPointRef': u'MTA_303017'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:01:55.417-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1831.55,
#             u'DistanceFromCall': 1285.67,
#             u'PresentableDistance': u'0.8 miles away',
#             u'StopsFromCall': 6}},
#           u'StopPointName': u'FULTON ST/LAFAYETTE AV',
#           u'StopPointRef': u'MTA_302368'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:04:11.017-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2085.33,
#             u'DistanceFromCall': 1539.44,
#             u'PresentableDistance': u'1.0 miles away',
#             u'StopsFromCall': 7}},
#           u'StopPointName': u'FULTON ST/S PORTLAND AV',
#           u'StopPointRef': u'MTA_302369'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:05:09.067-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2214.42,
#             u'DistanceFromCall': 1668.53,
#             u'PresentableDistance': u'1.0 miles away',
#             u'StopsFromCall': 8}},
#           u'StopPointName': u'GREENE AV/FULTON ST',
#           u'StopPointRef': u'MTA_307547'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:06:13.129-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2427.7,
#             u'DistanceFromCall': 1881.81,
#             u'PresentableDistance': u'1.2 miles away',
#             u'StopsFromCall': 9}},
#           u'StopPointName': u'GREENE AV/ADELPHI ST',
#           u'StopPointRef': u'MTA_307548'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:07:13.929-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2599.71,
#             u'DistanceFromCall': 2053.83,
#             u'PresentableDistance': u'1.3 miles away',
#             u'StopsFromCall': 10}},
#           u'StopPointName': u'GREENE AV/VANDERBILT AV',
#           u'StopPointRef': u'MTA_307549'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:08:45.729-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2849.35,
#             u'DistanceFromCall': 2303.46,
#             u'PresentableDistance': u'1.4 miles away',
#             u'StopsFromCall': 11}},
#           u'StopPointName': u'GREENE AV/WASHINGTON AV',
#           u'StopPointRef': u'MTA_307550'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:09:56.046-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3107.79,
#             u'DistanceFromCall': 2561.9,
#             u'PresentableDistance': u'1.6 miles away',
#             u'StopsFromCall': 12}},
#           u'StopPointName': u'GREENE AV/GRAND AV',
#           u'StopPointRef': u'MTA_307551'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:11:01.662-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3346.41,
#             u'DistanceFromCall': 2800.52,
#             u'PresentableDistance': u'1.7 miles away',
#             u'StopsFromCall': 13}},
#           u'StopPointName': u'GREENE AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307552'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:12:06.462-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3579.59,
#             u'DistanceFromCall': 3033.7,
#             u'PresentableDistance': u'1.9 miles away',
#             u'StopsFromCall': 14}},
#           u'StopPointName': u'FRANKLIN AV/GREENE AV',
#           u'StopPointRef': u'MTA_307553'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:13:11.662-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3827.24,
#             u'DistanceFromCall': 3281.35,
#             u'PresentableDistance': u'2.0 miles away',
#             u'StopsFromCall': 15}},
#           u'StopPointName': u'GATES AV/FRANKLIN AV',
#           u'StopPointRef': u'MTA_307674'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:14:56.630-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4010.77,
#             u'DistanceFromCall': 3464.89,
#             u'PresentableDistance': u'2.2 miles away',
#             u'StopsFromCall': 16}},
#           u'StopPointName': u'GATES AV/BEDFORD AV',
#           u'StopPointRef': u'MTA_307675'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:15:59.376-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4274.94,
#             u'DistanceFromCall': 3729.06,
#             u'PresentableDistance': u'2.3 miles away',
#             u'StopsFromCall': 17}},
#           u'StopPointName': u'GATES AV/NOSTRAND AV',
#           u'StopPointRef': u'MTA_307676'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:18:14.990-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4600.33,
#             u'DistanceFromCall': 4054.44,
#             u'PresentableDistance': u'2.5 miles away',
#             u'StopsFromCall': 18}},
#           u'StopPointName': u'GATES AV/MARCY AV',
#           u'StopPointRef': u'MTA_307677'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:19:40.288-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4849.89,
#             u'DistanceFromCall': 4304.0,
#             u'PresentableDistance': u'2.7 miles away',
#             u'StopsFromCall': 19}},
#           u'StopPointName': u'GATES AV/TOMPKINS AV',
#           u'StopPointRef': u'MTA_307678'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:21:07.039-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5087.05,
#             u'DistanceFromCall': 4541.16,
#             u'PresentableDistance': u'2.8 miles away',
#             u'StopsFromCall': 20}},
#           u'StopPointName': u'GATES AV/THROOP AV',
#           u'StopPointRef': u'MTA_307679'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:22:26.039-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5326.1,
#             u'DistanceFromCall': 4780.21,
#             u'PresentableDistance': u'3.0 miles away',
#             u'StopsFromCall': 21}},
#           u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#           u'StopPointRef': u'MTA_307680'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:23:44.651-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5574.85,
#             u'DistanceFromCall': 5028.96,
#             u'PresentableDistance': u'3.1 miles away',
#             u'StopsFromCall': 22}},
#           u'StopPointName': u'GATES AV/LEWIS AV',
#           u'StopPointRef': u'MTA_307681'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:25:04.290-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5826.46,
#             u'DistanceFromCall': 5280.57,
#             u'PresentableDistance': u'3.3 miles away',
#             u'StopsFromCall': 23}},
#           u'StopPointName': u'GATES AV/STUYVESANT AV',
#           u'StopPointRef': u'MTA_307682'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:26:35.634-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.85,
#             u'DistanceFromCall': 5529.96,
#             u'PresentableDistance': u'3.4 miles away',
#             u'StopsFromCall': 24}},
#           u'StopPointName': u'GATES AV/MALCOLM X BL',
#           u'StopPointRef': u'MTA_307683'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:27:55.834-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6321.91,
#             u'DistanceFromCall': 5776.02,
#             u'PresentableDistance': u'3.6 miles away',
#             u'StopsFromCall': 25}},
#           u'StopPointName': u'GATES AV/PATCHEN AV',
#           u'StopPointRef': u'MTA_307684'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:29:01.034-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6555.96,
#             u'DistanceFromCall': 6010.07,
#             u'PresentableDistance': u'3.7 miles away',
#             u'StopsFromCall': 26}},
#           u'StopPointName': u'GATES AV/RALPH AV',
#           u'StopPointRef': u'MTA_307901'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:30:02.676-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6717.8,
#             u'DistanceFromCall': 6171.91,
#             u'PresentableDistance': u'3.8 miles away',
#             u'StopsFromCall': 27}},
#           u'StopPointName': u'GATES AV/BROADWAY',
#           u'StopPointRef': u'MTA_307686'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:32:01.066-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6962.31,
#             u'DistanceFromCall': 6416.42,
#             u'PresentableDistance': u'4.0 miles away',
#             u'StopsFromCall': 28}},
#           u'StopPointName': u'GATES AV/BUSHWICK AV',
#           u'StopPointRef': u'MTA_307687'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:32:54.114-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7131.71,
#             u'DistanceFromCall': 6585.82,
#             u'PresentableDistance': u'4.1 miles away',
#             u'StopsFromCall': 29}},
#           u'StopPointName': u'GATES AV/EVERGREEN AV',
#           u'StopPointRef': u'MTA_307688'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:34:04.180-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7373.59,
#             u'DistanceFromCall': 6827.7,
#             u'PresentableDistance': u'4.2 miles away',
#             u'StopsFromCall': 30}},
#           u'StopPointName': u'GATES AV/CENTRAL AV',
#           u'StopPointRef': u'MTA_307689'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:35:08.780-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7576.02,
#             u'DistanceFromCall': 7030.13,
#             u'PresentableDistance': u'4.4 miles away',
#             u'StopsFromCall': 31}},
#           u'StopPointName': u'GATES AV/WILSON AV',
#           u'StopPointRef': u'MTA_307690'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:36:18.767-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7782.09,
#             u'DistanceFromCall': 7236.2,
#             u'PresentableDistance': u'4.5 miles away',
#             u'StopsFromCall': 32}},
#           u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#           u'StopPointRef': u'MTA_307691'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:37:42.188-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8081.37,
#             u'DistanceFromCall': 7535.48,
#             u'PresentableDistance': u'4.7 miles away',
#             u'StopsFromCall': 33}},
#           u'StopPointName': u'PALMETTO ST/IRVING AV',
#           u'StopPointRef': u'MTA_304415'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:38:18.388-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8231.28,
#             u'DistanceFromCall': 7685.39,
#             u'PresentableDistance': u'4.8 miles away',
#             u'StopsFromCall': 34}},
#           u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#           u'StopPointRef': u'MTA_801117'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_307175',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.693035, u'Longitude': -73.989117},
#        u'VehicleRef': u'MTA NYCT_3985'},
#       u'RecordedAtTime': u'2017-09-21T13:50:56.000-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 337.64383,
# ...
#             u'PresentableDistance': u'4.9 miles away',
#             u'StopsFromCall': 33}},
#           u'StopPointName': u'JORALEMON ST/COURT ST',
#           u'StopPointRef': u'MTA_302434'},
#          {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8059.65,
#             u'DistanceFromCall': 7983.21,
#             u'PresentableDistance': u'5.0 miles away',
#             u'StopsFromCall': 34}},
#           u'StopPointName': u'CADMAN PLZ W/MONTAGUE ST',
#           u'StopPointRef': u'MTA_306533'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:44:46.731-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91,
#             u'DistanceFromCall': 8021.47,
#             u'PresentableDistance': u'5.0 miles away',
#             u'StopsFromCall': 35}},
#           u'StopPointName': u'CADMAN PZ W/TILLARY ST',
#           u'StopPointRef': u'MTA_901463'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_504965',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.700925, u'Longitude': -73.910473},
#        u'VehicleRef': u'MTA NYCT_4046'},
#       u'RecordedAtTime': u'2017-09-21T13:51:06.224-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 44.379494,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday_C_FP_26340_B52-119',
#        u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#        u'DestinationRef': u'MTA_901463',
#        u'DirectionRef': u'1',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-21',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-081800_B26_18'},
#        u'JourneyPatternRef': u'MTA_B520048',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-21T13:51:36.396-04:00',
#         u'ExpectedDepartureTime': u'2017-09-21T13:51:36.396-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 242.63,
#           u'DistanceFromCall': 238.06,
#           u'PresentableDistance': u'< 1 stop away',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'GATES AV/WYCKOFF AV',
#         u'StopPointRef': u'MTA_504119',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-21T13:51:36.396-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 242.63,
#             u'DistanceFromCall': 238.06,
#             u'PresentableDistance': u'< 1 stop away',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'GATES AV/WYCKOFF AV',
#           u'StopPointRef': u'MTA_504119'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:53:44.235-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 501.59,
#             u'DistanceFromCall': 497.02,
#             u'PresentableDistance': u'1 stop away',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'GATES AV/IRVING AV',
#           u'StopPointRef': u'MTA_304196'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:54:54.835-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 724.62,
#             u'DistanceFromCall': 720.05,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#           u'StopPointRef': u'MTA_304197'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:56:02.035-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 918.53,
#             u'DistanceFromCall': 913.96,
#             u'PresentableDistance': u'0.6 miles away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'GATES AV/WILSON AV',
#           u'StopPointRef': u'MTA_304198'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:57:18.134-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1127.58,
#             u'DistanceFromCall': 1123.0,
#             u'PresentableDistance': u'0.7 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'GATES AV/CENTRAL AV',
#           u'StopPointRef': u'MTA_304199'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:58:39.981-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1369.74,
#             u'DistanceFromCall': 1365.17,
#             u'PresentableDistance': u'0.8 miles away',
#             u'StopsFromCall': 5}},
#           u'StopPointName': u'GATES AV/EVERGREEN AV',
#           u'StopPointRef': u'MTA_304200'},
#          {u'ExpectedArrivalTime': u'2017-09-21T13:59:50.770-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1539.93,
#             u'DistanceFromCall': 1535.36,
#             u'PresentableDistance': u'1.0 miles away',
#             u'StopsFromCall': 6}},
#           u'StopPointName': u'GATES AV/BUSHWICK AV',
#           u'StopPointRef': u'MTA_304201'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:01:32.066-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1755.61,
#             u'DistanceFromCall': 1751.04,
#             u'PresentableDistance': u'1.1 miles away',
#             u'StopsFromCall': 7}},
#           u'StopPointName': u'GATES AV/BROADWAY',
#           u'StopPointRef': u'MTA_308046'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:02:58.866-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1901.08,
#             u'DistanceFromCall': 1896.51,
#             u'PresentableDistance': u'1.2 miles away',
#             u'StopsFromCall': 8}},
#           u'StopPointName': u'GATES AV/RALPH AV',
#           u'StopPointRef': u'MTA_304203'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:04:35.066-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2178.14,
#             u'DistanceFromCall': 2173.57,
#             u'PresentableDistance': u'1.4 miles away',
#             u'StopsFromCall': 9}},
#           u'StopPointName': u'GATES AV/PATCHEN AV',
#           u'StopPointRef': u'MTA_304204'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:05:50.925-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2430.58,
#             u'DistanceFromCall': 2426.01,
#             u'PresentableDistance': u'1.5 miles away',
#             u'StopsFromCall': 10}},
#           u'StopPointName': u'GATES AV/MALCOLM X BL',
#           u'StopPointRef': u'MTA_304205'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:07:25.525-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2679.29,
#             u'DistanceFromCall': 2674.72,
#             u'PresentableDistance': u'1.7 miles away',
#             u'StopsFromCall': 11}},
#           u'StopPointName': u'GATES AV/STUYVESANT AV',
#           u'StopPointRef': u'MTA_304206'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:08:31.213-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2883.11,
#             u'DistanceFromCall': 2878.54,
#             u'PresentableDistance': u'1.8 miles away',
#             u'StopsFromCall': 12}},
#           u'StopPointName': u'GATES AV/LEWIS AV',
#           u'StopPointRef': u'MTA_304207'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:10:34.613-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3177.93,
#             u'DistanceFromCall': 3173.36,
#             u'PresentableDistance': u'2.0 miles away',
#             u'StopsFromCall': 13}},
#           u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#           u'StopPointRef': u'MTA_306530'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:11:40.013-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3373.19,
#             u'DistanceFromCall': 3368.62,
#             u'PresentableDistance': u'2.1 miles away',
#             u'StopsFromCall': 14}},
#           u'StopPointName': u'GATES AV/THROOP AV',
#           u'StopPointRef': u'MTA_304209'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:13:42.813-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3659.93,
#             u'DistanceFromCall': 3655.35,
#             u'PresentableDistance': u'2.3 miles away',
#             u'StopsFromCall': 15}},
#           u'StopPointName': u'GATES AV/TOMPKINS AV',
#           u'StopPointRef': u'MTA_304210'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:15:19.213-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3902.63,
#             u'DistanceFromCall': 3898.06,
#             u'PresentableDistance': u'2.4 miles away',
#             u'StopsFromCall': 16}},
#           u'StopPointName': u'GATES AV/MARCY AV',
#           u'StopPointRef': u'MTA_304211'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:17:26.621-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4182.76,
#             u'DistanceFromCall': 4178.19,
#             u'PresentableDistance': u'2.6 miles away',
#             u'StopsFromCall': 17}},
#           u'StopPointName': u'GATES AV/NOSTRAND AV',
#           u'StopPointRef': u'MTA_304212'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:19:29.727-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4496.51,
#             u'DistanceFromCall': 4491.94,
#             u'PresentableDistance': u'2.8 miles away',
#             u'StopsFromCall': 18}},
#           u'StopPointName': u'GATES AV/BEDFORD AV',
#           u'StopPointRef': u'MTA_304213'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:20:51.829-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4675.5,
#             u'DistanceFromCall': 4670.93,
#             u'PresentableDistance': u'2.9 miles away',
#             u'StopsFromCall': 19}},
#           u'StopPointName': u'GATES AV/FRANKLIN AV',
#           u'StopPointRef': u'MTA_304214'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:21:46.972-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4864.08,
#             u'DistanceFromCall': 4859.51,
#             u'PresentableDistance': u'3.0 miles away',
#             u'StopsFromCall': 20}},
#           u'StopPointName': u'GATES AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307948'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:23:39.372-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5156.7,
#             u'DistanceFromCall': 5152.13,
#             u'PresentableDistance': u'3.2 miles away',
#             u'StopsFromCall': 21}},
#           u'StopPointName': u'GREENE AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307572'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:24:49.972-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5398.69,
#             u'DistanceFromCall': 5394.12,
#             u'PresentableDistance': u'3.4 miles away',
#             u'StopsFromCall': 22}},
#           u'StopPointName': u'GREENE AV/GRAND AV',
#           u'StopPointRef': u'MTA_307573'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:26:35.076-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5656.47,
#             u'DistanceFromCall': 5651.9,
#             u'PresentableDistance': u'3.5 miles away',
#             u'StopsFromCall': 23}},
#           u'StopPointName': u'GREENE AV/WASHINGTON AV',
#           u'StopPointRef': u'MTA_307596'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:28:06.219-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5908.9,
#             u'DistanceFromCall': 5904.33,
#             u'PresentableDistance': u'3.7 miles away',
#             u'StopsFromCall': 24}},
#           u'StopPointName': u'GREENE AV/VANDERBILT AV',
#           u'StopPointRef': u'MTA_307575'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:28:57.219-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.28,
#             u'DistanceFromCall': 6070.71,
#             u'PresentableDistance': u'3.8 miles away',
#             u'StopsFromCall': 25}},
#           u'StopPointName': u'GREENE AV/ADELPHI ST',
#           u'StopPointRef': u'MTA_307576'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:30:00.819-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6239.48,
#             u'DistanceFromCall': 6234.91,
#             u'PresentableDistance': u'3.9 miles away',
#             u'StopsFromCall': 26}},
#           u'StopPointName': u'GREENE AV/CUMBERLAND ST',
#           u'StopPointRef': u'MTA_307577'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:32:12.244-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6482.4,
#             u'DistanceFromCall': 6477.83,
#             u'PresentableDistance': u'4.0 miles away',
#             u'StopsFromCall': 27}},
#           u'StopPointName': u'FULTON ST/S ELLIOTT PL',
#           u'StopPointRef': u'MTA_302427'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:33:28.844-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6639.55,
#             u'DistanceFromCall': 6634.98,
#             u'PresentableDistance': u'4.1 miles away',
#             u'StopsFromCall': 28}},
#           u'StopPointName': u'FULTON ST/FT GREENE PL',
#           u'StopPointRef': u'MTA_302428'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:35:10.644-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6938.8,
#             u'DistanceFromCall': 6934.23,
#             u'PresentableDistance': u'4.3 miles away',
#             u'StopsFromCall': 29}},
#           u'StopPointName': u'FULTON ST/HUDSON AV',
#           u'StopPointRef': u'MTA_302430'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:37:13.844-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7188.7,
#             u'DistanceFromCall': 7184.13,
#             u'PresentableDistance': u'4.5 miles away',
#             u'StopsFromCall': 30}},
#           u'StopPointName': u'FULTON ST/BOND ST',
#           u'StopPointRef': u'MTA_302431'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:38:35.644-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7394.01,
#             u'DistanceFromCall': 7389.43,
#             u'PresentableDistance': u'4.6 miles away',
#             u'StopsFromCall': 31}},
#           u'StopPointName': u'FULTON ST/DUFFIELD ST',
#           u'StopPointRef': u'MTA_307492'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:40:03.804-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7604.3,
#             u'DistanceFromCall': 7599.73,
#             u'PresentableDistance': u'4.7 miles away',
#             u'StopsFromCall': 32}},
#           u'StopPointName': u'FULTON ST/JAY ST',
#           u'StopPointRef': u'MTA_302433'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:42:50.804-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7929.74,
#             u'DistanceFromCall': 7925.17,
#             u'PresentableDistance': u'4.9 miles away',
#             u'StopsFromCall': 33}},
#           u'StopPointName': u'JORALEMON ST/COURT ST',
#           u'StopPointRef': u'MTA_302434'},
#          {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8059.65,
#             u'DistanceFromCall': 8055.08,
#             u'PresentableDistance': u'5.0 miles away',
#             u'StopsFromCall': 34}},
#           u'StopPointName': u'CADMAN PLZ W/MONTAGUE ST',
#           u'StopPointRef': u'MTA_306533'},
#          {u'ExpectedArrivalTime': u'2017-09-21T14:44:23.604-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91,
#             u'DistanceFromCall': 8093.34,
#             u'PresentableDistance': u'5.0 miles away',
#             u'StopsFromCall': 35}},
#           u'StopPointName': u'CADMAN PZ W/TILLARY ST',
#           u'StopPointRef': u'MTA_901463'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_504965',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.700503, u'Longitude': -73.910046},
#        u'VehicleRef': u'MTA NYCT_6530'},
#       u'RecordedAtTime': u'2017-09-21T13:50:55.000-04:00'}]}]}}

# %%
# Outputs the following to the console: bus name, # of vehicles, current position

# creates a variable that stores path to VehicleActivity in MTA JSON tree
veh_act = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']

# print the bus name
print("Bus Name: " + veh_act[0]['MonitoredVehicleJourney']['PublishedLineName'])

# print number of vehicles in the bus line
print("Number of Vehicles: " + str(len(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'])))

# print the current position of each bus

buscount = len(veh_act)
for i in range(buscount):
    Long = veh_act[i]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']
    Lat = veh_act[i]['MonitoredVehicleJourney']['VehicleLocation']['Latitude']
    veh_act[i]['MonitoredVehicleJourney']['VehicleLocation']
    print("Bus " + str(i) + " is at latitude " + str(Lat) + " and longitude " + str(Long))
# Out:
# Bus Name: B52
# Number of Vehicles: 12
# Bus 0 is at latitude 40.685235 and longitude -73.959113
# Bus 1 is at latitude 40.686534 and longitude -73.947838
# Bus 2 is at latitude 40.689427 and longitude -73.922613
# Bus 3 is at latitude 40.688886 and longitude -73.927378
# Bus 4 is at latitude 40.693035 and longitude -73.989117
# Bus 5 is at latitude 40.686505 and longitude -73.974913
# Bus 6 is at latitude 40.690117 and longitude -73.984004
# Bus 7 is at latitude 40.686031 and longitude -73.971724
# Bus 8 is at latitude 40.698403 and longitude -73.913315
# Bus 9 is at latitude 40.690003 and longitude -73.983712
# Bus 10 is at latitude 40.700925 and longitude -73.910473
# Bus 11 is at latitude 40.700503 and longitude -73.910046
