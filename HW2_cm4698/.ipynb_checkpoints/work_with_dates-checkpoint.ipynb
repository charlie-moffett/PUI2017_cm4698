# %%
import os
import sys

import pandas as pd

# Checks that an environmental variable DFDATA exists and that it points to the data facility location 

DFdata = os.getenv("DFDATA")

# %%
# Uses pandas to read in the CSV file from the DF into a pandas dataframe

df_medallions = pd.read_csv(DFdata + '/h9gi-nx95/1482192000/h9gi-nx95.csv')
df_medallions.head()
# Out:
#          DATE   TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  02/09/2017  17:15       NaN       NaN  40.677357 -73.886870
# 1  02/09/2017  18:30     BRONX   10454.0  40.804283 -73.917274
# 2  02/09/2017  18:31     BRONX   10466.0  40.892040 -73.858140
# 3  02/09/2017  18:43  BROOKLYN   11218.0  40.641070 -73.985825
# 4  08/25/2015  19:00       NaN       NaN  40.732941 -73.920382
#
#                     LOCATION   ON STREET NAME  CROSS STREET NAME  \
# 0     (40.677357, -73.88687)  ATLANTIC AVENUE                NaN
# 1    (40.804283, -73.917274)              NaN                NaN
# 2      (40.89204, -73.85814)  EAST 231 STREET  WHITE PLAINS ROAD
# 3     (40.64107, -73.985825)              NaN                NaN
# 4  (40.7329414, -73.9203819)              NaN                NaN
#
#              OFF STREET NAME         ...          \
# 0                        NaN         ...
# 1  617       EAST 135 STREET         ...
# 2                        NaN         ...
# ...

# %%
# Removes all but 2 numerical values columns of my choice
df_medallions = df_medallions[['DATE', 'NUMBER OF PERSONS INJURED']]
df_medallions.head()
# Out:
#          DATE  NUMBER OF PERSONS INJURED
# 0  02/09/2017                          0
# 1  02/09/2017                          0
# 2  02/09/2017                          1
# 3  02/09/2017                          0
# 4  08/25/2015                          0

# %%
# setting up some preferences
import pylab as pl
# %pylab inline
pl.rc('font', size=15)

#df_medallions['License Expiration Date'] = pd.to_datetime(df_medallions['License Expiration Date'])
df_med = pd.to_datetime(df_medallions['DATE'])

# turning my 2 numerical values columns into x and y data
y = df_medallions['NUMBER OF PERSONS INJURED']
x = df_med

# setting x and y axes labels and title
pl.xlabel("Date")
pl.ylabel("# of people")
pl.title("Number of people injured in collisons by date")
#pl.text(-3, -5000, "scatter plotting one column against another from DFDATA with dates")
pl.xticks(rotation='vertical')

# Plot the columns one against the other in a scatter plot
pl.plot(x, y, ".")
pl.xticks(rotation='vertical')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (array([ 734777.,  734959.,  735142.,  735324.,  735507.,  735689.,
#          735872.,  736055.,  736238.]), <a list of 9 Text xticklabel objects>)
